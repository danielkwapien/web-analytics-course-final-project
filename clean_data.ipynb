# %% [markdown]
# # Prepare the data

# %% [markdown]
# ## 1. Import and clean the data
#
# First we will import and clean the data extracted from the TicketMaster API.

# %%
import pandas as pd

# %%
events_df = pd.read_csv('./data/events_usa.csv')
events_df
# Out:
# /var/folders/cg/jyq82rhn3xd2pzr3wjw1vl400000gn/T/ipykernel_3811/739173356.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   events_df = pd.read_csv('./data/events_usa.csv')
#                                   event_id  \
# 0                          1AeFZbaGkB3eo2V
# 1        Za5ju3rKuqZB0JrpXv_We8znm28cgibgP
# 2       Za5ju3rKuqZDdlPN-oVRykBnF3vfK5Ko7x
# 3                    LvZ18_rWx_gI4QYZvJg2t
# 4                            G5dYZb6MeRvaX
# ...                                    ...
# 135226   Za5ju3rKuqZB9QSO5q6qAYhtjo6tcEIva
# 135227   Za5ju3rKuqZB6eQ8FkGW2EQMk3lk-4jlh
# 135228  Za5ju3rKuqZDdFGHPmaiauiliA9JEIZ6Wf
# 135229   Za5ju3rKuqZBLSMdi-Io50bdJnsV1iyn6
# 135230  Za5ju3rKuqZDehr7_mlVWGWD0wHDQAQtbp
#
#                                                event_name event_type  \
# 0                                        Mosconi Cup 2024      event
# 1                                     Shark Reef Aquarium      event
# 2                                                Gondolas      event
# 3                  Las Vegas - Immersive Disney Animation      event
# 4       Christmas Spectacular Starring The Radio City ...      event
# ...                                                   ...        ...
# 135226                                              BENEE      event
# 135227                                                KES      event
# 135228                                     Jetsetter Pass      event
# 135229                        Fall Fest presented by GEHA      event
# 135230                        Fall Fest presented by GEHA      event
#
#                                                 event_url locale  start_date  \
# 0       https://www.ticketmaster.com/mosconi-cup-2024-...  en-us  2024-12-02
# 1                                                     NaN  en-us  2024-12-02
# 2                                                     NaN  en-us  2024-12-02
# 3       https://www.universe.com/events/las-vegas-imme...  en-us  2024-12-02
# 4       https://www.ticketmaster.com/christmas-spectac...  en-us  2024-12-02
# ...                                                   ...    ...         ...
# 135226                                                NaN  en-us  6022-09-30
# 135227                                                NaN  en-us  6022-10-01
# 135228                                                NaN  en-us  7022-07-08
# 135229                                                NaN  en-us  9999-09-09
# 135230                                                NaN  en-us  9999-09-09
#
#        start_time             timezone   status  \
# 0        13:00:00     America/New_York   onsale
# 1        10:00:00  America/Los_Angeles  offsale
# 2        10:00:00  America/Los_Angeles  offsale
# 3        10:45:00  America/Los_Angeles   onsale
# 4        14:00:00     America/New_York   onsale
# ...           ...                  ...      ...
# 135226   19:00:00  America/Los_Angeles  offsale
# 135227   19:00:00  America/Los_Angeles  offsale
# 135228   08:00:00      America/Chicago  offsale
# 135229   10:00:00      America/Chicago  offsale
# 135230   14:00:00      America/Chicago  offsale
#
#                                   venue_id  ... venue_latitude  \
# 0                             KovZpZA7eaIA  ...      28.357492
# 1       Za5ju3rKuqZDeFydbojccenhe0ZKOhuimR  ...      36.092397
# 2       Za5ju3rKuqZDvx2EhiFIsAKl5EE9LweZOJ  ...      36.121200
# 3                              KovZ917AJRQ  ...      36.107966
# 4                             KovZpZAE7vdA  ...      40.759914
# ...                                    ...  ...            ...
# 135226  Za5ju3rKuqZDeXbS0-23o7c_vVJZY-QyfS  ...      38.569919
# 135227  Za5ju3rKuqZDeXbS0-23o7c_vVJZY-QyfS  ...      38.569919
# 135228   Za5ju3rKuqZBpDh7taWs27BYgPk_Hh2E5  ...      33.520428
# 135229   Za5ju3rKuqZBw0SE3LuP56_iwzhRcUsKv  ...            NaN
# 135230   Za5ju3rKuqZBw0SE3LuP56_iwzhRcUsKv  ...            NaN
#
#        venue_longitude    segment_name     genre_name sub_genre_name  \
# 0           -81.493406          Sports  Miscellaneous  Miscellaneous
# 1          -115.175984             NaN            NaN            NaN
# 2           115.169700             NaN            NaN            NaN
# 3          -115.174475   Miscellaneous      Undefined      Undefined
# 4           -73.980398  Arts & Theatre        Theatre        Musical
# ...                ...             ...            ...            ...
# 135226     -121.493130             NaN            NaN            NaN
# 135227     -121.493130             NaN            NaN            NaN
# 135228      -86.771561             NaN            NaN            NaN
# 135229             NaN             NaN            NaN            NaN
# 135230             NaN             NaN            NaN            NaN
#
#        attraction_id                                    attraction_name  \
# 0        K8vZ917oO5f                                        Mosconi Cup
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3        K8vZ917Qs70  Disney Animation: Immersive Experience - Las V...
# 4        K8vZ9171K10  Christmas Spectacular Starring The Radio City ...
# ...              ...                                                ...
# 135226           NaN                                                NaN
# 135227           NaN                                                NaN
# 135228           NaN                                                NaN
# 135229           NaN                                                NaN
# 135230           NaN                                                NaN
#
#         min_price max_price currency
# 0            70.0     500.0      USD
# 1             NaN       NaN      NaN
# 2             NaN       NaN      NaN
# 3             NaN       NaN      USD
# 4            80.0     160.0      USD
# ...           ...       ...      ...
# 135226        NaN       NaN      NaN
# 135227        NaN       NaN      NaN
# 135228        NaN       NaN      NaN
# 135229        NaN       NaN      NaN
# 135230        NaN       NaN      NaN
#
# [135231 rows x 26 columns]

# %%
events_df = events_df[events_df['status'] == 'onsale']
events_df = events_df.dropna()
events_df
# Out:
#                event_id                                         event_name  \
# 0       1AeFZbaGkB3eo2V                                   Mosconi Cup 2024
# 4         G5dYZb6MeRvaX  Christmas Spectacular Starring The Radio City ...
# 21        k7vGFbuKtVbxa  Sullivan 180 Walk-thru Mondays At Peace, Love ...
# 23        G5vzZb1UbOv0d     Denver Broncos v Cleveland Browns VIP Tailgate
# 29       rZ7HnEZ1AKpaa7                  Vince Giordano and the Nighthawks
# ...                 ...                                                ...
# 134126    G5eZZ96Duyl5J                               Event for Calendar 1
# 134129    G5eZZ96DCtl5V                               Event for Calendar 2
# 134133  17FZvOG62UECvY3                               Event for Calendar 2
# 134135  17FZvOG62MkSx61                               Event for Calendar 2
# 134260  17FZvOG6uKWReZu                           Sponsorship - Google Pay
#
#        event_type                                          event_url locale  \
# 0           event  https://www.ticketmaster.com/mosconi-cup-2024-...  en-us
# 4           event  https://www.ticketmaster.com/christmas-spectac...  en-us
# 21          event  https://www.ticketmaster.com/sullivan-180-walk...  en-us
# 23          event  https://www.ticketmaster.com/denver-broncos-v-...  en-us
# 29          event  https://www.ticketweb.com/event/vince-giordano...  en-us
# ...           ...                                                ...    ...
# 134126      event  https://www.ticketmaster.com/event-for-calenda...  en-us
# 134129      event  https://www.ticketmaster.com/event-for-calenda...  en-us
# 134133      event  https://www.ticketmaster.com/event-for-calenda...  en-us
# 134135      event  https://www.ticketmaster.com/event-for-calenda...  en-us
# 134260      event  https://www.ticketmaster.com/sponsorship-googl...  en-us
#
#         start_date start_time          timezone  status       venue_id  ...  \
# 0       2024-12-02   13:00:00  America/New_York  onsale   KovZpZA7eaIA  ...
# 4       2024-12-02   14:00:00  America/New_York  onsale   KovZpZAE7vdA  ...
# 21      2024-12-02   17:00:00  America/New_York  onsale   KovZpZAEAd1A  ...
# 23      2024-12-02   15:15:00    America/Denver  onsale     KovZpa3Wne  ...
# 29      2024-12-02   17:30:00  America/New_York  onsale  rZ7HnEZ174KrF  ...
# ...            ...        ...               ...     ...            ...  ...
# 134126  2026-04-07   20:00:00  America/New_York  onsale    KovZ917ALpY  ...
# 134129  2026-04-08   20:00:00  America/New_York  onsale    KovZ917ALpY  ...
# 134133  2026-04-11   20:00:00  America/New_York  onsale    KovZ917AJpm  ...
# 134135  2026-04-12   20:00:00  America/New_York  onsale    KovZ917AJpm  ...
# 134260  2026-06-20   19:30:00  America/New_York  onsale    KovZ917ALpY  ...
#
#        venue_latitude venue_longitude    segment_name     genre_name  \
# 0           28.357492      -81.493406          Sports  Miscellaneous
# 4           40.759914      -73.980398  Arts & Theatre        Theatre
# 21          41.696889      -74.877974   Miscellaneous         Family
# 23          39.743853     -105.020127          Sports       Football
# 29          40.759017      -73.989686           Music           Rock
# ...               ...             ...             ...            ...
# 134126      33.822426      -84.370392  Arts & Theatre          Dance
# 134129      33.822426      -84.370392  Arts & Theatre          Dance
# 134133      33.749000      -84.388000  Arts & Theatre          Dance
# 134135      33.749000      -84.388000  Arts & Theatre          Dance
# 134260      33.822426      -84.370392           Music            Pop
#
#        sub_genre_name attraction_id  \
# 0       Miscellaneous   K8vZ917oO5f
# 4             Musical   K8vZ9171K10
# 21              Other   K8vZ917_dp7
# 23                NFL   K8vZ9171og7
# 29                Pop   K8vZ917uP3V
# ...               ...           ...
# 134126          Dance   K8vZ9175n90
# 134129          Dance   K8vZ9175n90
# 134133          Dance   K8vZ9175n90
# 134135          Dance   K8vZ9175n90
# 134260            Pop   K8vZ917pkj7
#
#                                           attraction_name  min_price  \
# 0                                             Mosconi Cup      70.00
# 4       Christmas Spectacular Starring The Radio City ...      80.00
# 21                                   Peace, Love & Lights      12.00
# 23                                         Denver Broncos     135.00
# 29                      Vince Giordano and the Nighthawks      24.91
# ...                                                   ...        ...
# 134126                                       Dance & Chat       5.00
# 134129                                       Dance & Chat       5.00
# 134133                                       Dance & Chat      50.00
# 134135                                       Dance & Chat      50.00
# 134260                                        Test artist      44.50
#
#        max_price currency
# 0         500.00      USD
# 4         160.00      USD
# 21         12.00      USD
# 23        135.00      USD
# 29         45.76      USD
# ...          ...      ...
# 134126     10.00      USD
# 134129     10.00      USD
# 134133     50.00      USD
# 134135     50.00      USD
# 134260    134.25      USD
#
# [43502 rows x 26 columns]

# %% [markdown]
# At the beggining we had too much data because we collected all the events from the API. We filtered the data to only include events that are on sale and have a price. We also removed the events that have any missing values. With that, we are left with 43,502 events.

# %% [markdown]
# ## 2. Prepare the datasets
#
# Now we will prepare the datasets we need to be used in the streamlit app

# %%
events_df['average_price'] = events_df[['min_price', 'max_price']].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Universidad/4Datos/Web-Analytics/final-project/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price_min'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Compute average price
# ----> 2 events_df['price_min'] = events_df['price_min'].mean(axis=1)
#
# File ~/Universidad/4Datos/Web-Analytics/final-project/venv/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Universidad/4Datos/Web-Analytics/final-project/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'price_min'

# %%
events_df.to_csv('./data/events.csv', index=False)

# %%
prices_by_city = events_df.groupby('venue_city').agg({'min_price':'mean', 'max_price':'mean', 'average_price':'mean', 'venue_latitude':'mean', 'venue_longitude':'mean'}).reset_index()
prices_by_city.to_csv('./data/prices_by_city.csv', index=False)

# %%
state_name_to_abbreviation = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR',
    'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE',
    'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID',
    'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS',
    'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
    'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV',
    'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY',
    'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT',
    'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV',
    'Wisconsin': 'WI', 'Wyoming': 'WY'
}

# %%
events_df["venue_state_code"] = events_df["venue_state"].map(state_name_to_abbreviation)

# %%
prices_by_state = events_df.groupby('venue_state_code').agg({'min_price':'mean', 'max_price':'mean', 'average_price':'mean'}).reset_index()
prices_by_state.to_csv('./data/prices_by_state.csv', index=False)
